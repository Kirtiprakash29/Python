# %% [markdown]
# Q1. Explain why we have to use exception class while creating custom exception
#
# Custom Exception by name itself signify the customisation of error handling. Built-in exception are already present with known error and its types.However, custom are the ones used specifically for problem/project related issues. Thus exception class is required to cutomise our requirement of handling anticipated exceptions

# %% [markdown]
# Q2. Write a python program to print python exception hierarchy.

# %%
import inspect
def tree_class(cls, ind = 0):
    print ('-' * ind, cls.__name__)
    for i in cls.__subclasses__():
        tree_class(i, ind + 3)
print ("Inbuilt exceptions is: ")
inspect.getclasstree(inspect.getmro(BaseException))
tree_class(BaseException)
# Out:
# Inbuilt exceptions is:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %% [markdown]
# Q3. What errors are defined in ArithmeticError class? Explain any two with example.
#
# Overflow error,ZeroDivisionError,FloatingPoint Error are in Arithmetic Error class.

# %%
#ZeroDivision Error
a=10
b=a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 #ZeroDivision Error
#       2 a=10
# ----> 3 b=a/0
#
# ZeroDivisionError: division by zero

# %%
print(10.2-10.0)
#This (10.2-10) should be 0.2. This error can be handled using round() function
# Out:
# 0.1999999999999993

# %%
# To handle above we use Decimal class
from decimal import *
print(Decimal('10.2')-Decimal('10.0'))
# Out:
# 0.2

# %% [markdown]
# Q4. Why LookUpError Class is used? Explain with an example IndexError and keyError?
#
# LookUpError is exception wherein this class is called when something that is looked up but hasn't been found-neither in normal sequence nor in key

# %%
#Index Error
x = [1,2,3,4]
x[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 #Index Error
#       2 x = [1,2,3,4]
# ----> 3 x[10]
#
# IndexError: list index out of range

# %%
#Handle Index Error
x=[1,2,3,4]
try:
    x[10]
except IndexError:
    print("Index error has come. So printing this")
# Out:
# Index error has come. So printing this

# %%
#Key Error
d ={'Name' : 'Harsh',
    'City' : 'Bangalore',
    'Phone': 987654321}
d['Qualification']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 5
#       1 #Key Error
#       2 d ={'Name' : 'Harsh',
#       3     'City' : 'Bangalore',
#       4     'Phone': 987654321}
# ----> 5 d['Qualification']
#
# KeyError: 'Qualification'

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?
#
# ImportError occurs when module or member of module is not imported

# %%
import sys
from time import dateTime
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 2
#       1 import sys
# ----> 2 from time import dateTime
#
# ImportError: cannot import name 'dateTime' from 'time' (unknown location)

# %%
#ModuleNotFoundError
from test1 import class1
class class2:
    obj.class1()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 2
#       1 #ModuleNotFoundError
# ----> 2 from test1 import class1
#       3 class class2:
#       4     obj.class1()
#
# ModuleNotFoundError: No module named 'test1'

# %% [markdown]
# Q6. List down some of best practices for exception handling in python
#
# Usage of try,except,else,finally
# Use of Relevant and specific exceptions while using except
# Logging error in separate error logging file
# For user defined anticipated errors, use custom exception
